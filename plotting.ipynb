# %% [markdown]
# # Plotting

# %% [markdown]
# PYroMat class methods natively support numpy arrays, which makes plotting easy.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pyromat as pm
T = np.linspace(273.,1800.)
air = pm.get('ig.air')

# %%
plt.plot(T, air.cp(T))

# %%
plt.plot(T, air.h(T))
