# %% [markdown]
# <a href="https://colab.research.google.com/github/phystopia/pyromat-thermodynamics/blob/main/sat_diagrams_R1234ze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyromat
import pyromat as pm
import numpy as np
import matplotlib.pyplot as plt

pm.config["unit_pressure"] = "kPa"

R1234ze = pm.get("mp.C3H2F4_1")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 14.9 MB/s
# ...
#   Created wheel for pyromat: filename=PYroMat-2.2.4-py3-none-any.whl size=1009766 sha256=7f39bbb3815a7fddd249f352b2d50d52c0f1c417245c1eed28d09135fbfa7180
#   Stored in directory: /root/.cache/pip/wheels/80/78/c3/2de108a92ae9b163466ae3cebba2e1e53245550c1abcf62df7
# Successfully built pyromat
# ...

# %%
pm.info(R1234ze)
# Out:
# ***
# Information summary for substance: "mp.C3H2F4_1"
# ***
#
#     C H F
#      3 2 4
#
#              Names : R-1234ze(E)
#                      C3H2F4
#                      1,3,3,3-tetrafluoroprop-1-ene
#                      (E)-1,3,3,3-tetrafluoroprop-1-ene
#                      (E)-1,3,3,3-tetrafluoropropene
#                      HFO-1234ze
#   Molecular Weight : 114.0416
#         CAS number : 29118-24-9
#       InChI string : InChI=1S/C3H2F4/c4-2-1-3(5,6)7/h1-2H/b2-1+
#         Data class : mp1
#        Loaded from : /usr/local/lib/python3.7/dist-packages/pyromat/data/mp/C3_H2_F4_1.hpd
#       Last updated : 0:58 November 1, 2022
#
# Equations of state are adapted from: M. Thol, E. Lemmon, Equation of state
# for the thermodynamic properties of trans-1,3,3,3-tetrafluoropropene
# [R1234ze(E)]

# %% [markdown]
# ## Minimum pressure, Critical pressure

# %%
p = np.arange(0.3,3635)

# %% [markdown]
# ## Saturation P-v Diagram for Tetrafluoroethane (R-1234ze)

# %%
v = R1234ze.vs(p=p)
vf= v[0]
vg= v[1]

# %%
font = {'family' : 'Helvetica',
        'size'   : 22}
plt.figure(figsize=(30,10))
plt.xscale("log")
plt.yscale("log")
plt.title('Saturation P-v Diagram for Solstice ze (R-1234ze)')
plt.rc('font', **font)
plt.plot(vf,p, 'b--')
plt.plot(vg,p,'r--')
plt.ylabel('Pressure (kPa)')
plt.xlabel('specific volume (m3/kg)')
# Out:
# Text(0.5, 0, 'specific volume (m3/kg)')

# %%
font = {'family' : 'Helvetica',
        'size'   : 22}
plt.figure(figsize=(30,10))
plt.title('Saturation P-v Diagram for Solstice ze (R-1234ze)')
plt.rc('font', **font)
plt.xlim([0,0.1])
plt.plot(vf,p, 'b--')
plt.plot(vg,p,'r--')
plt.ylabel('Pressure (kPa)')
plt.xlabel('specific volume (m3/kg)')
# Out:
# Text(0.5, 0, 'specific volume (m3/kg)')

# %%
## Saturation T-s Diagram for Solstice ze (R-1234ze)

# %%
T = R1234ze.Ts(p=p)
s = R1234ze.ss(p=p)

# %%
font = {'family' : 'Helvetica',
        'size'   : 22}
plt.figure(figsize=(15,10))
# plt.xscale("log")
# plt.yscale("log")
plt.title('Saturation T-s Diagram for Solstice ze (R-1234ze)')
plt.rc('font', **font)
plt.plot(s[0], T, 'b--')
plt.plot(s[1], T,'r--')
plt.ylabel('Temperature (kPa)')
plt.xlabel('specific enthropy (kJ/kg)')
# Out:
# Text(0.5, 0, 'specific enthropy (kJ/kg)')
